# %%
import pandas as pd 
import numpy as np
dataset=pd.read_csv("3_employees.csv")

dataset.head(3)
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas     Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer    Whalen   JWHALEN  515.123.4444  17-SEP-03
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10

# %%
dataset.head(5)
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
dataset.tail(5)
# Out:
#     EMPLOYEE_ID FIRST_NAME   LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 45          136      Hazel  Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 46          137     Renske      Ladwig   RLADWIG  650.121.1234  14-JUL-03
# 47          138    Stephen      Stiles   SSTILES  650.121.2034  26-OCT-05
# 48          139       John         Seo      JSEO  650.121.2019  12-FEB-06
# 49          140     Joshua       Patel    JPATEL  650.121.1834  06-APR-06
#
#       JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 45  ST_CLERK    2200             -         122             50
# 46  ST_CLERK    3600             -         123             50
# 47  ST_CLERK    3200             -         123             50
# 48  ST_CLERK    2700             -         123             50
# 49  ST_CLERK    2500             -         123             50

# %%
dataset.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# EMPLOYEE_ID       0
# FIRST_NAME        0
# LAST_NAME         0
# EMAIL             0
# PHONE_NUMBER      0
# HIRE_DATE         0
# JOB_ID            0
# SALARY            0
# COMMISSION_PCT    0
# MANAGER_ID        0
# DEPARTMENT_ID     0
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %%
dataset.iloc[11:20]
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 12          103  Alexander     Hunold   AHUNOLD  590.423.4567  03-JAN-06
# 13          104      Bruce      Ernst    BERNST  590.423.4568  21-MAY-07
# 14          105      David     Austin   DAUSTIN  590.423.4569  25-JUN-05
# 15          106      Valli  Pataballa  VPATABAL  590.423.4560  05-FEB-06
# 16          107      Diana    Lorentz  DLORENTZ  590.423.5567  07-FEB-07
# 17          108      Nancy  Greenberg  NGREENBE  515.124.4569  17-AUG-02
# 18          109     Daniel     Faviet   DFAVIET  515.124.4169  16-AUG-02
# 19          110       John       Chen     JCHEN  515.124.4269  28-SEP-05
#
#         JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 11       AD_VP   17000             -         100             90
# 12     IT_PROG    9000             -         102             60
# ...

# %%
dataset.iloc[11:20 ,0:3]
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME
# 11          102        Lex    De Haan
# 12          103  Alexander     Hunold
# 13          104      Bruce      Ernst
# 14          105      David     Austin
# 15          106      Valli  Pataballa
# 16          107      Diana    Lorentz
# 17          108      Nancy  Greenberg
# 18          109     Daniel     Faviet
# 19          110       John       Chen

# %%
dataset.iloc[11:20:2]
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 13          104      Bruce      Ernst    BERNST  590.423.4568  21-MAY-07
# 15          106      Valli  Pataballa  VPATABAL  590.423.4560  05-FEB-06
# 17          108      Nancy  Greenberg  NGREENBE  515.124.4569  17-AUG-02
# 19          110       John       Chen     JCHEN  515.124.4269  28-SEP-05
#
#         JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 11       AD_VP   17000             -         100             90
# 13     IT_PROG    6000             -         103             60
# 15     IT_PROG    4800             -         103             60
# 17      FI_MGR   12008             -         101            100
# 19  FI_ACCOUNT    8200             -         108            100

# %%
dataset.iloc[[1,6,3,9,13,2],[1,4]]
# Out:
#    FIRST_NAME  PHONE_NUMBER
# 1     Douglas  650.507.9844
# 6     Hermann  515.123.8888
# 3     Michael  515.123.5555
# 9      Steven  515.123.4567
# 13      Bruce  590.423.4568
# 2    Jennifer  515.123.4444

# %%
dataset.notnull().sum()
# Out:
# EMPLOYEE_ID       50
# FIRST_NAME        50
# LAST_NAME         50
# EMAIL             50
# PHONE_NUMBER      50
# HIRE_DATE         50
# JOB_ID            50
# SALARY            50
# COMMISSION_PCT    50
# MANAGER_ID        50
# DEPARTMENT_ID     50
# dtype: int64

# %%
fd=dataset.replace({"Male","Female"},{0,1})
fd
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
dataset.sort_values("FIRST_NAME")
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 30          121         Adam        Fripp    AFRIPP  650.123.2234  10-APR-05
# 24          115    Alexander         Khoo     AKHOO  515.127.4562  18-MAY-03
# 12          103    Alexander       Hunold   AHUNOLD  590.423.4567  03-JAN-06
# 13          104        Bruce        Ernst    BERNST  590.423.4568  21-MAY-07
# 18          109       Daniel       Faviet   DFAVIET  515.124.4169  16-AUG-02
# 14          105        David       Austin   DAUSTIN  590.423.4569  25-JUN-05
# 23          114          Den     Raphaely  DRAPHEAL  515.127.4561  07-DEC-02
# 16          107        Diana      Lorentz  DLORENTZ  590.423.5567  07-FEB-07
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 27          118          Guy       Himuro   GHIMURO  515.127.4565  15-NOV-06
# ...

# %%
dataset.dtypes
# Out:
# EMPLOYEE_ID        int64
# FIRST_NAME        object
# LAST_NAME         object
# EMAIL             object
# PHONE_NUMBER      object
# HIRE_DATE         object
# JOB_ID            object
# SALARY             int64
# COMMISSION_PCT    object
# MANAGER_ID        object
# DEPARTMENT_ID      int64
# dtype: object

# %%
dataset.fillna(0)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
dataset.describe()
# Out:
#        EMPLOYEE_ID        SALARY  DEPARTMENT_ID
# count    50.000000     50.000000       50.00000
# mean    134.760000   6182.320000       57.60000
# std      33.631594   4586.181772       25.11687
# min     100.000000   2100.000000       10.00000
# 25%     112.250000   2725.000000       50.00000
# 50%     124.500000   4600.000000       50.00000
# 75%     136.750000   8150.000000       60.00000
# max     206.000000  24000.000000      110.00000

# %%
fd=dataset["SALARY"]=dataset["SALARY"].astype("float")
fd
# Out:
# 0      2600.0
# 1      2600.0
# 2      4400.0
# 3     13000.0
# 4      6000.0
# 5      6500.0
# 6     10000.0
# 7     12008.0
# 8      8300.0
# 9     24000.0
# 10    17000.0
# 11    17000.0
# 12     9000.0
# 13     6000.0
# 14     4800.0
# 15     4800.0
# 16     4200.0
# 17    12008.0
# 18     9000.0
# 19     8200.0
# 20     7700.0
# 21     7800.0
# 22     6900.0
# 23    11000.0
# 24     3100.0
# 25     2900.0
# 26     2800.0
# 27     2600.0
# 28     2500.0
# 29     8000.0
# 30     8200.0
# 31     7900.0
# 32     6500.0
# 33     5800.0
# 34     3200.0
# 35     2700.0
# 36     2400.0
# 37     2200.0
# 38     3300.0
# 39     2800.0
# 40     2500.0
# 41     2100.0
# 42     3300.0
# 43     2900.0
# 44     2400.0
# 45     2200.0
# 46     3600.0
# 47     3200.0
# 48     2700.0
# 49     2500.0
# Name: SALARY, dtype: float64

# %%
dataset.dtypes
# Out:
# EMPLOYEE_ID         int64
# FIRST_NAME         object
# LAST_NAME          object
# EMAIL              object
# PHONE_NUMBER       object
# HIRE_DATE          object
# JOB_ID             object
# SALARY            float64
# COMMISSION_PCT     object
# MANAGER_ID         object
# DEPARTMENT_ID       int64
# dtype: object

# %%
dataset.fillna(0)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
dataset.fillna(3)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
# calculate the mean vaule for "stroke" column
mean = dataset["SALARY"].astype("float").mean(axis=0)
print("Average of salary:", mean)
# Out:
# Average of salary: 6182.32

# %%
# calculate the mean vaule for "stroke" column
median = dataset["SALARY"].astype("float").median(axis = 0)
print("Average of salary:", median)
# Out:
# Average of salary: 4600.0

# %%
mode_salary = dataset["SALARY"].astype(float).mode()[0]
print("Mode of salary:", mode_salary)
# Out:
# Mode of salary: 2500.0

# %%
print(dataset.dtypes)
# Out:
# EMPLOYEE_ID         int64
# FIRST_NAME         object
# LAST_NAME          object
# EMAIL              object
# PHONE_NUMBER       object
# HIRE_DATE          object
# JOB_ID             object
# SALARY            float64
# COMMISSION_PCT     object
# MANAGER_ID         object
# DEPARTMENT_ID       int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# Apply Z-Score on a numeric column (e.g., 'salary')
if 'SALARY' in dataset.columns:
    dataset['SALARY_z'] = zscore(dataset['SALARY'].dropna())

    # Box plot of original salary
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=dataset['SALARY'])
    plt.title('Box plot of Salary')
    plt.show()
