# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Dataset
data = {
    'Experience': [5, 7, 9, 12, 18, 20],
    'Salary': [20000, 25000, 40000, 60000, 80000, 110000]
}

df = pd.DataFrame(data)

# Reshape for sklearn
X = df[['Experience']]  # feature must be 2D
y = df['Salary']

# Model
model = LinearRegression()
model.fit(X, y)

# Predict salary for 15 years of experience
predicted_salary = model.predict([[15]])
print(f"Predicted Salary for 15 years of experience: ₹{predicted_salary[0]:.2f}")

# Optional: Plot
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.title('Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.show()
# Out:
# D:\Users\NIKITA\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Salary for 15 years of experience: ₹73687.33
